# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('wine_data.csv', header=None, usecols=[0,4,5,6])

# %%
df.columns = ['Class','Alcanicity', 'Magne', 'Tot_Phenols']
df
# Out:
#      Class  Alcanicity  Magne  Tot_Phenols
# 0        1        15.6    127         2.80
# 1        1        11.2    100         2.65
# 2        1        18.6    101         2.80
# 3        1        16.8    113         3.85
# 4        1        21.0    118         2.80
# ..     ...         ...    ...          ...
# 173      3        20.5     95         1.68
# 174      3        23.0    102         1.80
# 175      3        20.0    120         1.59
# 176      3        20.0    120         1.65
# 177      3        24.5     96         2.05
#
# [178 rows x 4 columns]

# %% [markdown]
# # splitting data

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.1, random_state=42)

# %%
X_train = pd.DataFrame(X_train, columns=x.columns)
X_test = pd.DataFrame(X_test, columns=x.columns)

# %%
X_train
# Out:
#      Alcanicity  Magne  Tot_Phenols
# 9          16.0     98         2.98
# 114        22.5     84         2.56
# 18         16.5    108         3.30
# 66         15.0     78         2.98
# 60         16.0    101         2.05
# ..          ...    ...          ...
# 71         25.0     86         2.95
# 106        19.0     80         1.65
# 14         12.0    102         3.30
# 92         20.7     80         1.38
# 102        21.0     98         2.56
#
# [160 rows x 3 columns]

# %%
X_test
# Out:
#      Alcanicity  Magne  Tot_Phenols
# 19         15.2    116         2.70
# 45         18.9    111         2.85
# 140        21.0     96         1.54
# 30         22.5    101         3.00
# 67         19.6     78         2.11
# 16         20.0    120         2.80
# 119        19.0     87         2.00
# 174        23.0    102         1.80
# 109        20.0     94         2.74
# 141        20.0     89         1.40
# 24         20.0     96         2.53
# 150        24.0    123         1.40
# 41         18.8     90         2.45
# 118        16.0     80         1.63
# 15         17.2    112         2.85
# 111        21.0     88         2.55
# 113        21.0     88         2.48
# 82         24.0     78         2.00

# %% [markdown]
# # Scaling the values Absolutely

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=x.columns)
X_train_scaled
# Out:
#      Alcanicity     Magne  Tot_Phenols
# 0      0.533333  0.604938     0.768041
# 1      0.750000  0.518519     0.659794
# 2      0.550000  0.666667     0.850515
# 3      0.500000  0.481481     0.768041
# 4      0.533333  0.623457     0.528351
# ..          ...       ...          ...
# 155    0.833333  0.530864     0.760309
# 156    0.633333  0.493827     0.425258
# 157    0.400000  0.629630     0.850515
# 158    0.690000  0.493827     0.355670
# 159    0.700000  0.604938     0.659794
#
# [160 rows x 3 columns]

# %%
X_train.describe()
# Out:
#        Alcanicity      Magne  Tot_Phenols
# count  160.000000  160.00000   160.000000
# mean    19.430625  100.03125     2.298125
# std      3.426332   14.30768     0.636180
# min     10.600000   70.00000     0.980000
# 25%     17.000000   88.00000     1.735000
# 50%     19.050000   98.00000     2.335000
# 75%     21.500000  107.00000     2.800000
# max     30.000000  162.00000     3.880000

# %%
X_train_scaled.describe()
# Out:
#        Alcanicity       Magne  Tot_Phenols
# count  160.000000  160.000000   160.000000
# mean     0.647687    0.617477     0.592300
# std      0.114211    0.088319     0.163964
# min      0.353333    0.432099     0.252577
# 25%      0.566667    0.543210     0.447165
# 50%      0.635000    0.604938     0.601804
# 75%      0.716667    0.660494     0.721649
# max      1.000000    1.000000     1.000000

# %%
sns.scatterplot(X_train['Alcanicity'])
# Out:
# <Axes: ylabel='Alcanicity'>

# %%
sns.scatterplot(X_train_scaled['Alcanicity'])
# Out:
# <Axes: ylabel='Alcanicity'>

# %%
sns.scatterplot(x='Alcanicity', y='Magne', data=X_train)
# Out:
# <Axes: xlabel='Alcanicity', ylabel='Magne'>

# %%
sns.scatterplot(x='Alcanicity', y='Magne', data=X_train_scaled)
# Out:
# <Axes: xlabel='Alcanicity', ylabel='Magne'>
