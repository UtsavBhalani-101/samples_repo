# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('wine_data.csv', header=None, usecols=[0,1,2,3])

# %%
df.columns = ['Class', 'Alcohol', 'Malic Acid', 'Ash']
df
# Out:
#      Class  Alcohol  Malic Acid   Ash
# 0        1    14.23        1.71  2.43
# 1        1    13.20        1.78  2.14
# 2        1    13.16        2.36  2.67
# 3        1    14.37        1.95  2.50
# 4        1    13.24        2.59  2.87
# ..     ...      ...         ...   ...
# 173      3    13.71        5.65  2.45
# 174      3    13.40        3.91  2.48
# 175      3    13.27        4.28  2.26
# 176      3    13.17        2.59  2.37
# 177      3    14.13        4.10  2.74
#
# [178 rows x 4 columns]

# %% [markdown]
# # first we split the data

# %%
x = df.drop('Class', axis=1)      # ----> here the 'class' is the name and axis is the identifier -- 0 for row and 1 for cols
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.1, random_state=42)

# %% [markdown]
# # now we normalize the data - min max scaling

# %%
X_test = pd.DataFrame(X_test)
X_test
# Out:
#      Alcohol  Malic Acid   Ash
# 19     13.64        3.10  2.56
# 45     14.21        4.04  2.44
# 140    12.93        2.81  2.70
# 30     13.73        1.50  2.70
# 67     12.37        1.17  1.92
# 16     14.30        1.92  2.72
# 119    12.00        3.43  2.00
# 174    13.40        3.91  2.48
# 109    11.61        1.35  2.70
# 141    13.36        2.56  2.35
# 24     13.50        1.81  2.61
# 150    13.50        3.12  2.62
# 41     13.41        3.84  2.12
# 118    12.77        3.43  1.98
# 15     13.63        1.81  2.70
# 111    12.52        2.43  2.17
# 113    11.41        0.74  2.50
# 82     12.08        1.13  2.51

# %%
X_train
# Out:
#      Alcohol  Malic Acid   Ash
# 9      13.86        1.35  2.27
# 114    12.08        1.39  2.50
# 18     14.19        1.59  2.48
# 66     13.11        1.01  1.70
# 60     12.33        1.10  2.28
# ..       ...         ...   ...
# 71     13.86        1.51  2.67
# 106    12.25        1.73  2.12
# 14     14.38        1.87  2.38
# 92     12.69        1.53  2.26
# 102    12.34        2.45  2.46
#
# [160 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = scaler.transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)

# %%
X_train_scaled.describe()
# Out:
#           Alcohol  Malic Acid         Ash
# count  160.000000  160.000000  160.000000
# mean     0.517993    0.291968    0.534291
# std      0.213046    0.229330    0.146560
# min      0.000000    0.000000    0.000000
# 25%      0.348684    0.146130    0.454545
# 50%      0.531579    0.191446    0.532086
# 75%      0.701316    0.429735    0.627005
# max      1.000000    1.000000    1.000000

# %%
X_test_scaled = pd.DataFrame(X_test, columns=X_test.columns)
X_test_scaled.describe()
# Out:
#          Alcohol  Malic Acid        Ash
# count  18.000000   18.000000  18.000000
# mean   13.020556    2.450000   2.432222
# std     0.855271    1.058401   0.275735
# min    11.410000    0.740000   1.920000
# 25%    12.407500    1.577500   2.215000
# 50%    13.380000    2.495000   2.505000
# 75%    13.597500    3.352500   2.680000
# max    14.300000    4.040000   2.720000

# %%
new = pd.DataFrame(X_train_scaled)
new.columns = ['Alcohol', 'Malic Acid', 'Ash']
new
# Out:
#       Alcohol  Malic Acid       Ash
# 0    0.744737    0.093686  0.486631
# 1    0.276316    0.101833  0.609626
# 2    0.831579    0.142566  0.598930
# 3    0.547368    0.024440  0.181818
# 4    0.342105    0.042770  0.491979
# ..        ...         ...       ...
# 155  0.744737    0.126273  0.700535
# 156  0.321053    0.171079  0.406417
# 157  0.881579    0.199593  0.545455
# 158  0.436842    0.130346  0.481283
# 159  0.344737    0.317719  0.588235
#
# [160 rows x 3 columns]

# %%
sns.scatterplot(x='Alcohol', y='Malic Acid', data=df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
sns.scatterplot(x='Alcohol', y='Malic Acid', data=new)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>
