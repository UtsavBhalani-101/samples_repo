# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
life = sns.load_dataset('healthexp')

# %%
life.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
life['Year'].value_counts()
# Out:
# Year
# 1980    6
# 1985    6
# 2013    6
# 2005    6
# 2006    6
# 2004    6
# 2003    6
# 2000    6
# 1999    6
# 2002    6
# 2001    6
# 1997    6
# 1998    6
# 1996    6
# 1995    6
# 1993    6
# 1994    6
# 1992    6
# 1990    6
# 2017    6
# 2014    6
# 2007    6
# 2008    6
# 2009    6
# 2010    6
# 2011    6
# 2012    6
# 2019    6
# 2018    6
# 2015    6
# 2016    6
# 2020    6
# 1970    5
# 1971    5
# 1988    5
# 1984    5
# 1981    5
# 1983    5
# 1982    5
# 1987    5
# 1986    5
# 1991    5
# 1989    5
# 1975    4
# 1979    4
# 1976    4
# 1973    3
# 1972    3
# 1974    3
# 1978    3
# 1977    3
# Name: count, dtype: int64

# %%
life['Country'].value_counts()
# Out:
# Country
# USA              51
# Japan            51
# Germany          50
# Canada           44
# Great Britain    43
# France           35
# Name: count, dtype: int64

# %%
sns.barplot(x='Year', y='Life_Expectancy', data=life)
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
life.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.ecdfplot(life['Life_Expectancy'])
# Out:
# <Axes: xlabel='Life_Expectancy', ylabel='Proportion'>

# %%
sns.ecdfplot(life['Spending_USD'])
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Proportion'>

# %%
sns.lineplot(x='Year', y='Life_Expectancy', data=life)
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
sns.pointplot(x='Year', y='Life_Expectancy', data=life)
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
sns.lineplot(x='Year', y='Spending_USD', data=life)
# Out:
# <Axes: xlabel='Year', ylabel='Spending_USD'>

# %%
sns.scatterplot(y='Life_Expectancy', x='Year', data=life, hue='Country')
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
sns.scatterplot(y='Spending_USD', x='Year', data=life, hue='Country')
# Out:
# <Axes: xlabel='Year', ylabel='Spending_USD'>

# %%
life.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.scatterplot(x='Life_Expectancy', y='Spending_USD', data=life, hue='Country')
# Out:
# <Axes: xlabel='Life_Expectancy', ylabel='Spending_USD'>

# %%
sns.barplot(y='Life_Expectancy', x='Country', data=life)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>
