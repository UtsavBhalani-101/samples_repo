# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wmt_data.csv')

# %%
df.head()
# Out:
#                         date       open       high        low      close  \
# 0  2000-01-03 00:00:00-05:00  22.791668  23.000000  21.833332  22.270832
# 1  2000-01-04 00:00:00-05:00  21.833332  21.937500  21.395832  21.437500
# 2  2000-01-05 00:00:00-05:00  21.291668  21.458332  20.729168  21.000000
# 3  2000-01-06 00:00:00-05:00  21.000000  21.520832  20.895832  21.229168
# 4  2000-01-07 00:00:00-05:00  21.500000  22.979168  21.500000  22.833332
#
#    adj_close    volume
# 0  14.307388  25109700
# 1  13.772032  20235300
# 2  13.490974  21056100
# 3  13.638196  19633500
# 4  14.668746  23930700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6345 entries, 0 to 6344
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6345 non-null   object
#  1   open       6345 non-null   float64
#  2   high       6345 non-null   float64
#  3   low        6345 non-null   float64
#  4   close      6345 non-null   float64
#  5   adj_close  6345 non-null   float64
#  6   volume     6345 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 347.1+ KB

# %%
ds = pd.read_csv('140325_LoL_champion_data.csv')

# %%
ds.sample(5)
# Out:
#     Unnamed: 0     id   apiname                     title  difficulty  \
# 110   Renekton   58.0  Renekton  the Butcher of the Sands           1
# 66     Kha'Zix  121.0    Khazix            the Voidreaver           2
# 20     Caitlyn   51.0   Caitlyn   the Sheriff of Piltover           1
# 72     Lee Sin   64.0    LeeSin            the Blind Monk           2
# 84       Milio  902.0     Milio          The Gentle Flame           1
#
#      herotype   alttype resource  \
# 110   Fighter      Tank     Fury
# 66   Assassin       NaN     Mana
# 20   Marksman       NaN     Mana
# 72    Fighter  Assassin   Energy
# 84    Support      Mage     Mana
#
#                                                  stats rangetype  ...    be  \
# 110  {'hp_base': 660, 'hp_lvl': 111, 'mp_base': 100...     Melee  ...  2400
# 66   {'hp_base': 643, 'hp_lvl': 99, 'mp_base': 327,...     Melee  ...  2400
# 20   {'hp_base': 580, 'hp_lvl': 107, 'mp_base': 315...    Ranged  ...   225
# ...

# %%
ds.drop('Unnamed: 0', axis=1, inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  172 non-null    float64
#  1   apiname             172 non-null    object
#  2   title               172 non-null    object
#  3   difficulty          172 non-null    int64
#  4   herotype            172 non-null    object
#  5   alttype             144 non-null    object
#  6   resource            167 non-null    object
#  7   stats               172 non-null    object
#  8   rangetype           172 non-null    object
#  9   date                172 non-null    object
#  10  patch               172 non-null    object
#  11  changes             172 non-null    object
#  12  role                172 non-null    object
#  13  client_positions    172 non-null    object
#  14  external_positions  172 non-null    object
# ...

# %%
ds['control']
# Out:
# 0      2
# 1      2
# 2      1
# 3      1
# 4      3
#       ..
# 167    2
# 168    2
# 169    2
# 170    2
# 171    3
# Name: control, Length: 172, dtype: int64

# %%
sns.scatterplot(y='control', x='difficulty', data=ds)
# Out:
# <Axes: xlabel='difficulty', ylabel='control'>

# %%
sns.pairplot(ds)

# %%
ds['herotype'] = ds['herotype'].astype('category')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  172 non-null    float64
#  1   apiname             172 non-null    object
#  2   title               172 non-null    object
#  3   difficulty          172 non-null    int64
#  4   herotype            172 non-null    category
#  5   alttype             144 non-null    object
#  6   resource            167 non-null    object
#  7   stats               172 non-null    object
#  8   rangetype           172 non-null    object
#  9   date                172 non-null    object
#  10  patch               172 non-null    object
#  11  changes             172 non-null    object
#  12  role                172 non-null    object
#  13  client_positions    172 non-null    object
#  14  external_positions  172 non-null    object
# ...

# %%
ds['role'] = ds['role'].astype('category')

# %%
ds['role'].value_counts()
# Out:
# role
# {'Marksman'}                  21
# {'Vanguard'}                  16
# {'Diver'}                     15
# {'Skirmisher'}                14
# {'Specialist'}                14
# {'Juggernaut'}                14
# {'Assassin'}                  13
# {'Battlemage'}                11
# {'Burst'}                     11
# {'Enchanter'}                  8
# {'Catcher'}                    7
# {'Artillery'}                  6
# {'Warden'}                     5
# {'Diver', 'Assassin'}          2
# {'Burst', 'Enchanter'}         2
# {'Burst', 'Assassin'}          1
# {'Burst', 'Artillery'}         1
# {'Assassin', 'Marksman'}       1
# {'Artillery', 'Marksman'}      1
# {'Burst', 'Catcher'}           1
# {'Catcher', 'Assassin'}        1
# {'Burst', 'Skirmisher'}        1
# {'Catcher', 'Marksman'}        1
# {'Diver', 'Skirmisher'}        1
# {'Enchanter', 'Warden'}        1
# {'Enchanter', 'Marksman'}      1
# {'Skirmisher', 'Assassin'}     1
# {'Warden', 'Skirmisher'}       1
# ...

# %%
ds['herotype'].value_counts()
# Out:
# herotype
# Fighter     49
# Mage        37
# Marksman    28
# Tank        24
# Assassin    17
# Support     17
# Name: count, dtype: int64

# %%
ds['damage'].value_counts()
# Out:
# damage
# 3    100
# 2     52
# 1     20
# Name: count, dtype: int64

# %%
ds['control'].value_counts()
# Out:
# control
# 2    83
# 1    45
# 3    44
# Name: count, dtype: int64

# %%
final = {}
temp = {}
lis = []
for i in ds['control'].value_counts():
    lis.append(i)

id = 0
val = 0

for i in ds['control'].unique():
    id = i
    val =
# Out:
# 2
# 1
# 3

# %%
lis
# Out:
# [83, 45, 44]

# %%
ds['control'].unique()
# Out:
# array([2, 1, 3])

# %%
temp = {}
lis = []

id = 0
val = 0


for k, v in zip(ds['control'].unique(), ds['control'].value_counts()):
    temp[k] = v

print(temp)
lis.append(temp)
print(lis)
# Out:
# {np.int64(2): 83, np.int64(1): 45, np.int64(3): 44}
# [{np.int64(2): 83, np.int64(1): 45, np.int64(3): 44}]
