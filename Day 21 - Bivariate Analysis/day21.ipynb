# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
titanic = pd.read_csv("train.csv")

# %%
tips = sns.load_dataset('tips')        # -- load_dataset - these datasets come with sns

# %%
plane = pd.read_csv('flights.csv')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 1. Scatterplot - num-num

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
g = sns.FacetGrid(tips, col="sex", row="smoker")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")

# %% [markdown]
# # 3. Barplot N-C

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(y='Fare', x='Sex', data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
sns.barplot(x='Pclass', y='Fare', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x='Pclass', y='Age', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x='Pclass', y='Fare', data=titanic, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x='Pclass', y='Age', data=titanic, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
ax = sns.barplot(x='Pclass', y='Fare', data=titanic, hue='Sex')

# %%
ax.set_title('Pclass v/s Fare')
# Out:
# Text(0.5, 1.0, 'Pclass v/s Fare')

# %% [markdown]
# # 3. Boxplot N-C

# %%
sns.boxplot(x='Sex', y='Age', data=titanic, hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4. Distplot N-C

# %%
sns.kdeplot(titanic['Age'])     #  distplot - depreciated
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(titanic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(titanic['Age'])

# %%
sns.displot(titanic['Age'], kde=True)

# %%
sns.displot(x='Age', hue='Sex', kind='kde', fill=False, data=titanic)

# %%
sns.displot(x='Age', hue='Sex', kind='kde', fill=False, data=titanic, col='Embarked')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False)
sns.distplot(titanic[titanic['Survived'] == 1]['Age'], hist=False)
# Out:
# C:\Users\UTSAV\AppData\Local\Temp\ipykernel_18040\2051304922.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False)
# C:\Users\UTSAV\AppData\Local\Temp\ipykernel_18040\2051304922.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
titanic[titanic['Survived'] == 0]['Age']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
pd.crosstab(titanic['Pclass'], titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %% [markdown]
# # 5. Heatmap (C-C)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Embarked').mean()['Survived']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %% [markdown]
# # 6. ClusterMap (C-C)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'], titanic['Survived']))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 sns.clustermap(pd.crosstab(titanic['SibSp'], titanic['Survived']))
#
# File ~\anaconda3\envs\mlc\Lib\site-packages\seaborn\matrix.py:1250, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1157 """
#    1158 Plot a matrix dataset as a hierarchically-clustered heatmap.
#    1159
#    (...)   1247
#    1248 """
#    1249 if _no_scipy:
# -> 1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
# ...

# %% [markdown]
# # 7. Pairplot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# # 8. Lineplot

# %%
plane.sample(5)
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 295673  295673  2013      8   17    1238.0            1209       29.0
# 129371  129371  2013      2   21    1412.0            1355       17.0
# 42933    42933  2013     10   17    2206.0            1935      151.0
# 225542  225542  2013      6    4    1711.0            1715       -4.0
# 48137    48137  2013     10   23    1615.0            1615        0.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 295673    1342.0            1316       26.0  ...   1191   N355JB    JFK  ACK
# 129371    1702.0            1647       15.0  ...   1783   N593JB    JFK  MCO
# 42933       44.0            2242      122.0  ...    208   N842UA    EWR  SEA
# 225542    1812.0            1829      -17.0  ...   1176   N216JB    EWR  BOS
# 48137     1906.0            1915       -9.0  ...     65   N3ADAA    JFK  DFW
#
#        air_time  distance  hour  minute            time_hour  \
# ...

# %%
plane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
# ...

# %%
sns.lineplot(x='year', y='sched_arr_time', data=plane)
# Out:
# <Axes: xlabel='year', ylabel='sched_arr_time'>

# %%
flight = sns.load_dataset('flights')

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
