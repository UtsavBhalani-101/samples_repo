# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Characters.csv', sep=';', on_bad_lines='skip')

# %%
df.sample(3)
# Out:
#       Id            Name  Gender  \
# 62    63    Bloody Baron    Male
# 102  103  Dedalus Diggle    Male
# 81    82   Pomona Sprout  Female
#
#                                                    Job       House     Wand  \
# 62                               Slytherin House Ghost   Slytherin  Unknown
# 102                                                NaN         NaN  Unknown
# 81   Professor of Herbology | Head of Hufflepuff House  Hufflepuff  Unknown
#
#           Patronus Species              Blood status Hair colour Eye colour  \
# 62         Unknown   Ghost  Pure-blood or half-blood         NaN        NaN
# 102  Non-corporeal   Human  Pure-blood or half-blood         NaN        NaN
# 81   Non-corporeal   Human  Pure-blood or half-blood         NaN       Grey
#
#                   Loyalty                                             Skills  \
# 62                    NaN                                 Controlling Peeves
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            140 non-null    int64
#  1   Name          140 non-null    object
#  2   Gender        139 non-null    object
#  3   Job           121 non-null    object
#  4   House         101 non-null    object
#  5   Wand          132 non-null    object
#  6   Patronus      123 non-null    object
#  7   Species       140 non-null    object
#  8   Blood status  123 non-null    object
#  9   Hair colour   123 non-null    object
#  10  Eye colour    86 non-null     object
#  11  Loyalty       89 non-null     object
#  12  Skills        113 non-null    object
#  13  Birth         127 non-null    object
#  14  Death         42 non-null     object
# dtypes: int64(1), object(14)
# memory usage: 16.5+ KB

# %%
# df['Gender'] = df['Gender'].astype('Category')
sns.countplot(x='Gender', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      90
# Female    49
# Name: count, dtype: int64

# %%
df[[df['Gender'] != 'Male']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df[[df['Gender'] != 'Male']]
#
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
sns.countplot(x='House', data=df)
# Out:
# <Axes: xlabel='House', ylabel='count'>

# %%
plt.pie(df['Age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mlc\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.pie(df['Age'])
#
# ...

# %%
sns.countplot(x='Blood status', data=df)
# Out:
# <Axes: xlabel='Blood status', ylabel='count'>

# %%
df['Blood status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
