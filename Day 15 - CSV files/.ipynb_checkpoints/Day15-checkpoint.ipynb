# %%
import pandas as pd

# %% [markdown]
# **From local**

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = pd.read_csv("tips.csv", sep='\t')
df1
# Out:
#     total_bill,tip,sex,smoker,day,time,size
# 0         16.99,1.01,Female,No,Sun,Dinner,2
# 1           10.34,1.66,Male,No,Sun,Dinner,3
# 2            21.01,3.5,Male,No,Sun,Dinner,3
# 3           23.68,3.31,Male,No,Sun,Dinner,2
# 4         24.59,3.61,Female,No,Sun,Dinner,4
# ..                                      ...
# 239         29.03,5.92,Male,No,Sat,Dinner,3
# 240       27.18,2.0,Female,Yes,Sat,Dinner,2
# 241         22.67,2.0,Male,Yes,Sat,Dinner,2
# 242         17.82,1.75,Male,No,Sat,Dinner,2
# 243       18.78,3.0,Female,No,Thur,Dinner,2
#
# [244 rows x 1 columns]

# %%
df = pd.read_csv("tips.csv", header=None)

# %%
df
# Out:
#               0     1       2       3     4       5     6
# 0    total_bill   tip     sex  smoker   day    time  size
# 1         16.99  1.01  Female      No   Sun  Dinner     2
# 2         10.34  1.66    Male      No   Sun  Dinner     3
# 3         21.01   3.5    Male      No   Sun  Dinner     3
# 4         23.68  3.31    Male      No   Sun  Dinner     2
# ..          ...   ...     ...     ...   ...     ...   ...
# 240       29.03  5.92    Male      No   Sat  Dinner     3
# 241       27.18   2.0  Female     Yes   Sat  Dinner     2
# 242       22.67   2.0    Male     Yes   Sat  Dinner     2
# 243       17.82  1.75    Male      No   Sat  Dinner     2
# 244       18.78   3.0  Female      No  Thur  Dinner     2
#
# [245 rows x 7 columns]

# %%
df = pd.read_csv("tips.csv", header=None, names=['Bill_Total', 'Tip_amount', 'Gender', 'Smoker ?', 'Week day', 'Time', 'Size of tip'])

# %%
df
# Out:
#      Bill_Total Tip_amount  Gender Smoker ? Week day    Time Size of tip
# 0    total_bill        tip     sex   smoker      day    time        size
# 1         16.99       1.01  Female       No      Sun  Dinner           2
# 2         10.34       1.66    Male       No      Sun  Dinner           3
# 3         21.01        3.5    Male       No      Sun  Dinner           3
# 4         23.68       3.31    Male       No      Sun  Dinner           2
# ..          ...        ...     ...      ...      ...     ...         ...
# 240       29.03       5.92    Male       No      Sat  Dinner           3
# 241       27.18        2.0  Female      Yes      Sat  Dinner           2
# 242       22.67        2.0    Male      Yes      Sat  Dinner           2
# 243       17.82       1.75    Male       No      Sat  Dinner           2
# 244       18.78        3.0  Female       No     Thur  Dinner           2
#
# [245 rows x 7 columns]

# %%
df = pd.read_csv("tips.csv", header=None, names=["Bill_Total", "Tip_amount", "Gender", "Smoker ?", "Week day", "Time", "Size of tip"])
df
# Out:
#      Bill_Total Tip_amount  Gender Smoker ? Week day    Time Size of tip
# 0    total_bill        tip     sex   smoker      day    time        size
# 1         16.99       1.01  Female       No      Sun  Dinner           2
# 2         10.34       1.66    Male       No      Sun  Dinner           3
# 3         21.01        3.5    Male       No      Sun  Dinner           3
# 4         23.68       3.31    Male       No      Sun  Dinner           2
# ..          ...        ...     ...      ...      ...     ...         ...
# 240       29.03       5.92    Male       No      Sat  Dinner           3
# 241       27.18        2.0  Female      Yes      Sat  Dinner           2
# 242       22.67        2.0    Male      Yes      Sat  Dinner           2
# 243       17.82       1.75    Male       No      Sat  Dinner           2
# 244       18.78        3.0  Female       No     Thur  Dinner           2
#
# [245 rows x 7 columns]

# %%
df = pd.read_csv("tips.csv", header=None, names=["Bill_Total", "Tip_amount", "Gender", "Smoker ?", "Week day", "Time", "Size of tip"], usecols=['Bill_Total', 'Tip_amount', 'Smoker ?'])

# %%
df
# Out:
#      Bill_Total Tip_amount Smoker ?
# 0    total_bill        tip   smoker
# 1         16.99       1.01       No
# 2         10.34       1.66       No
# 3         21.01        3.5       No
# 4         23.68       3.31       No
# ..          ...        ...      ...
# 240       29.03       5.92       No
# 241       27.18        2.0      Yes
# 242       22.67        2.0      Yes
# 243       17.82       1.75       No
# 244       18.78        3.0       No
#
# [245 rows x 3 columns]

# %%
def gender(sex):
    if sex == "Female":
        return 'F'
    elif sex == "Male":
        return 'M'
    else:
        return sex




converter = pd.read_csv('tips.csv', converters={'sex':gender})
converter
# Out:
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   F     No   Sun  Dinner     2
# 1         10.34  1.66   M     No   Sun  Dinner     3
# 2         21.01  3.50   M     No   Sun  Dinner     3
# 3         23.68  3.31   M     No   Sun  Dinner     2
# 4         24.59  3.61   F     No   Sun  Dinner     4
# ..          ...   ...  ..    ...   ...     ...   ...
# 239       29.03  5.92   M     No   Sat  Dinner     3
# 240       27.18  2.00   F    Yes   Sat  Dinner     2
# 241       22.67  2.00   M    Yes   Sat  Dinner     2
# 242       17.82  1.75   M     No   Sat  Dinner     2
# 243       18.78  3.00   F     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
converter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
dfs = pd.read_csv('tips.csv', chunksize=50)
for chunck in dfs:
    print(chunck)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...
