# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Chocolate Sales.csv")

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
# 1. how big is the data and it's shape

df.shape
# Out:
# (1094, 6)

# %%
df.size
# Out:
# 6564

# %%
# 2. how it looks like
df.sample(10)
# Out:
#         Sales Person    Country               Product       Date    Amount  \
# 75   Roddy Speechley     Canada             Milk Bars  13-Jul-22     $609
# 394   Beverie Moffet     Canada    Smooth Sliky Salty  28-Feb-22  $14,287
# 339   Curtice Advani     Canada      Fruit & Nut Bars  04-Apr-22   $4,193
# 64        Oby Sorrel      India       99% Dark & Pure  27-May-22  $10,255
# 844      Brien Boise      India        70% Dark Bites  14-Apr-22   $4,641
# 562       Oby Sorrel        USA   Baker's Choco Chips  12-Aug-22   $8,001
# 768      Van Tuxwell     Canada  Choco Coated Almonds  19-Aug-22   $2,282
# 900   Jehu Rudeforth         UK         85% Dark Bars  07-Jul-22   $5,502
# 369      Kaine Padly     Canada       99% Dark & Pure  24-Jun-22   $1,288
# 636   Curtice Advani  Australia        50% Dark Bites  29-Jun-22     $504
#
#      Boxes Shipped
# 75              32
# 394            370
# 339            195
# 64              11
# 844            413
# 562            120
# 768            296
# 900             64
# 369            409
# 636            232

# %%
# 3. check info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 51.4+ KB

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04   $5,320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df['Amount'] = df['Amount'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(1), datetime64[ns](1), int32(1), object(3)
# memory usage: 39.9+ KB

# %%
df['Amount'] = df['Amount'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(np.int32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   int32
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(1), datetime64[ns](1), int32(2), object(2)
# memory usage: 35.6+ KB

# %%
df['Country'] = df['Country'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   int32
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(1), datetime64[ns](1), int32(2), object(2)
# memory usage: 35.6+ KB

# %%
df['Boxes Shipped'] = df['Boxes Shipped'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   int32
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(1), datetime64[ns](1), int32(2), object(2)
# memory usage: 35.6+ KB

# %%
df.sample(5)
# Out:
#         Sales Person      Country              Product       Date  Amount  \
# 58      Barr Faughny    Australia     Fruit & Nut Bars 2022-06-30   15421
# 199      Van Tuxwell  New Zealand   Smooth Sliky Salty 2022-06-14    3115
# 1035  Curtice Advani           UK   Manuka Honey Choco 2022-02-07    1666
# 555    Kelci Walkden          USA  Spicy Special Slims 2022-04-29      77
# 1091    Ches Bonnell       Canada  Organic Choco Syrup 2022-07-26     574
#
#       Boxes Shipped
# 58               55
# 199              42
# 1035            106
# 555              69
# 1091            217

# %%
df.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date        Amount  Boxes Shipped
# count                           1094   1094.000000    1094.000000
# mean   2022-05-03 09:04:56.160877568   5652.308044     161.797989
# min              2022-01-03 00:00:00      7.000000       1.000000
# 25%              2022-03-02 00:00:00   2390.500000      70.000000
# 50%              2022-05-11 00:00:00   4868.500000     135.000000
# 75%              2022-07-04 00:00:00   8027.250000     228.750000
# max              2022-08-31 00:00:00  22050.000000     709.000000
# std                              NaN   4102.442014     121.544145

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#                  Amount  Boxes Shipped
# Amount         1.000000      -0.018827
# Boxes Shipped -0.018827       1.000000

# %%
df.sample(10)
# Out:
#             Sales Person      Country               Product       Date  \
# 942      Roddy Speechley    Australia         85% Dark Bars 2022-07-08
# 126       Dotty Strutley           UK          Almond Choco 2022-07-28
# 30           Van Tuxwell  New Zealand         85% Dark Bars 2022-05-24
# 308          Brien Boise    Australia         Drinking Coco 2022-07-27
# 174       Jehu Rudeforth    Australia        50% Dark Bites 2022-01-14
# 373         Jan Morforth        India   Peanut Butter Cubes 2022-01-04
# 671  Dennison Crosswaite           UK   Baker's Choco Chips 2022-01-17
# 994      Gunar Cockshoot           UK   Spicy Special Slims 2022-02-16
# 430  Dennison Crosswaite  New Zealand          Orange Choco 2022-03-16
# 852       Marney O'Breen       Canada  Caramel Stuffed Bars 2022-02-23
#
#      Amount  Boxes Shipped
# 942    4200             80
# 126   16114             96
# 30     1722            121
# 308    6832            156
# 174    5194            418
# 373    8092            178
# 671    2275            275
# 994   12488            200
# 430    4571            140
# 852    1372            614

# %%
df.describe(include='all')
# Out:
#          Sales Person    Country  Product                           Date  \
# count            1094       1094     1094                           1094
# unique             25          6       22                            NaN
# top     Kelci Walkden  Australia  Eclairs                            NaN
# freq               54        205       60                            NaN
# mean              NaN        NaN      NaN  2022-05-03 09:04:56.160877568
# min               NaN        NaN      NaN            2022-01-03 00:00:00
# 25%               NaN        NaN      NaN            2022-03-02 00:00:00
# 50%               NaN        NaN      NaN            2022-05-11 00:00:00
# 75%               NaN        NaN      NaN            2022-07-04 00:00:00
# max               NaN        NaN      NaN            2022-08-31 00:00:00
# std               NaN        NaN      NaN                            NaN
#
#               Amount  Boxes Shipped
# count    1094.000000    1094.000000
# unique           NaN            NaN
# top              NaN            NaN
# freq             NaN            NaN
# mean     5652.308044     161.797989
# min         7.000000       1.000000
# 25%      2390.500000      70.000000
# 50%      4868.500000     135.000000
# 75%      8027.250000     228.750000
# max     22050.000000     709.000000
# std      4102.442014     121.544145
